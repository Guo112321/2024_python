# %% [markdown]
# # Lab-4

# %% [markdown]
# # Seaborn Exercises

# %% [markdown]
# * Name:
# * Student ID:

# %% [markdown]
# ## Import Numpy, Panda and Matplotlib library

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import Dataset

# %%
ds = pd.read_csv("iris.csv")
ds.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %% [markdown]
# ## Exercises 1

# %%
plt = sns.distplot(ds["sepal.width"],bins=13)
plt.set_ylim(0,1.4)
plt.set_xlim(1.5, 4.5)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_17484\2123145468.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   plt = sns.distplot(ds["sepal.width"],bins=13)
# (1.5, 4.5)

# %% [markdown]
# ## Exercises 2

# %%
sns.pairplot(ds[["sepal.length", "sepal.width", "petal.length"]])
# Out:
# E:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Exercises 3

# %%
sns.boxplot(ds, orient='h')
# Out:
# <Axes: >

# %%
#Wrrite your understanding of the graph above?

# %%
#A box plot, or box-and-whisker plot,
#summarizes the distribution of data by displaying key statistics
#: minimum, first quartile (Q1), median (Q2), third quartile (Q3), and maximum. 
#It consists of a box representing the interquartile range (IQR) with the median line inside, 
#and "whiskers" extending to the minimum and maximum values. 
#Outliers may be shown as individual points or lines beyond the whiskers.

# %% [markdown]
# ## Exercises 4

# %%
# Write the code to show the graph below.
g = sns.PairGrid(ds)
g.map(sns.scatterplot)

# %% [markdown]
# ## Exercises 5

# %%
sns.pairplot(ds)
# Out:
# E:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Exercises 6

# %% [markdown]
# Create a Categorical Plot for the column Sex of the Titanic dataset.

# %%
ds_ttc=pd.read_csv("Titanic.csv")
#sns.countplot(x='Sex', data=ds_ttc)
sns.catplot(x='Sex',kind='count' , data=ds_ttc)
# Out:
# E:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# Please save as Pdf and submit in Blackboard Lab4.
