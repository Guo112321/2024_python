# %% [markdown]
# ___
# # Matplotlib Exercises
#
# Welcome to the exercises for reviewing matplotlib! Take your time with these, Matplotlib can be tricky to understand at first. These are relatively simple plots, but they can be hard if this is your first time with matplotlib, feel free to reference the solutions as you go along.
#
# Also don't worry if you find the matplotlib syntax frustrating, we actually won't be using it that often throughout the course, we will switch to using seaborn and pandas built-in visualization capabilities. But, those are built-off of matplotlib, which is why it is still important to get exposure to it!
#
# ** * NOTE: ALL THE COMMANDS FOR PLOTTING A FIGURE SHOULD ALL GO IN THE SAME CELL. SEPARATING THEM OUT INTO MULTIPLE CELLS MAY CAUSE NOTHING TO SHOW UP. * **
#
# # Exercises
#
# Follow the instructions to recreate the plots using this data:
#
# ## Data

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# ** Import matplotlib.pyplot as plt and set %matplotlib inline if you are using the jupyter notebook. What command do you use if you aren't using the jupyter notebook?**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# if not using the jupyter notebook, use ply.show()to present diagram in new windows

# %% [markdown]
# ## Exercise 1
#
# ** Follow along with these steps: **
# * ** Create a figure object called fig using plt.figure() **
# * ** Use add_axes to add an axis to the figure canvas at [0,0,1,1]. Call this new axis ax. **
# * ** Plot (x,y) on that axes and set the labels and titles to match the plot below:**

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_title("title")
# Out:
# Text(0.5, 1.0, 'title')

# %% [markdown]
# ## Exercise 2
# ** Create a figure object and put two axes on it, ax1 and ax2. Located at [0,0,1,1] and [0.2,0.5,.2,.2] respectively.**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2, 0.5, .2, .2])

# %% [markdown]
# ** Now plot (x,y) on both axes. And call your figure object to show it.**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2, 0.5, .2, .2])
ax1.plot(x,y)
ax2.plot(x,y)

# %% [markdown]
# ## Exercise 3
#
# ** Create the plot below by adding two axes to a figure object at [0,0,1,1] and [0.2,0.5,.4,.4]**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2, 0.5, .4, .4])

# %% [markdown]
# ** Now use x,y, and z arrays to recreate the plot below. Notice the xlimits and y limits on the inserted plot:**

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2, 0.5, .4, .4])
ax2.set_xlim(20,22)
ax2.set_ylim(30,50)
ax2.plot(x,y)
ax2.set_xlabel("x")
ax2.set_ylabel("y")
ax1.set_xlabel("x")
ax1.set_ylabel("z")
ax1.plot(x,z)

# %% [markdown]
# ## Exercise 4
#
# ** Use plt.subplots(nrows=1, ncols=2) to create the plot below.**

# %%
fig = plt.subplots(nrows=1, ncols=2)

# %% [markdown]
# ** Now plot (x,y) and (x,z) on the axes. Play around with the linewidth and style**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
ax1 = axes[0]
ax2 = axes[1]
ax1.plot(x,y,linestyle = '--')
ax2.plot(x,z,color = "red")

# %% [markdown]
# ** See if you can resize the plot by adding the figsize() argument in plt.subplots() are copying and pasting your previous code.**

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8, 2))
ax1 = axes[0]
ax2 = axes[1]
ax1.plot(x,y,linestyle = '--')
ax2.plot(x,z,color = "red")

# %% [markdown]
# ## Exercise 5
#
# * Read the dataset Titanic, create the dataframe and read all columns.
# * Plot the Age,Fare column information
# * Provide all columns information

# %%
import pandas as pd

df = pd.read_csv('titanic.csv')
plt.subplot(1, 2, 1)
df['Age'].plot(kind="hist")
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')

plt.subplot(1, 2, 2)
df['Fare'].plot(kind="hist")
plt.title('Fare Distribution')
plt.xlabel('Fare')
plt.ylabel('Frequency')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.1+ KB

# %% [markdown]
# Consider the x=np.arange(0,15,0.5),
# them plot (np.sin(x)), (np.sin(x+0.5)), (np.sin(x+1.0)), (np.cos(x))
# with different linestyle and linewidth.

# %%
x = np.arange(0, 15, 0.5)
plt.plot(x, np.sin(x), linestyle='-', color="red", label='sin(x)')
plt.plot(x, np.sin(x + 0.5), linestyle='--', color="black", label='sin(x+0.5)')
plt.plot(x, np.sin(x + 1.0), linestyle='-.', color="yellow", label='sin(x+1.0)')
plt.plot(x, np.cos(x), linestyle=':', color="blue", label='cos(x)')

# %% [markdown]
# ### Please submit as pdf file
