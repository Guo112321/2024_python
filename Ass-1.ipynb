# %% [markdown]
# # Assignment 1

# %% [markdown]
# #### Name: Guo Xinfu
# #### ID: n01611988

# %% [markdown]
# ### 1. Import numpy, pandas, vasualization libraries and set %matplotlib inline

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib .pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2. Check the info() of the df

# %%
df = pd.read_csv("WineQT.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1142 non-null   float64
#  1   volatile acidity      1139 non-null   float64
#  2   citric acid           1140 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1141 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1141 non-null   float64
#  12  Id                    1143 non-null   int64
# dtypes: float64(12), int64(1)
# memory usage: 116.2 KB

# %% [markdown]
# ### 3. Check the head of df

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4      5.0   0
# 1      9.8      5.0   1
# 2      9.8      5.0   2
# 3      9.8      6.0   3
# 4      9.4      5.0   4

# %% [markdown]
# ### 4. What are the top 5 alcohol for wine dataset?

# %%
df_top_alcohol = df.sort_values(by='alcohol', ascending=False).head(5)
df_top_alcohol
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 462           15.9              0.36         0.65             7.5      0.096
# 329            8.8              0.46         0.45             2.6      0.065
# 98             5.2              0.34         0.00             1.8      0.050
# 898            5.0              0.38         0.01             1.6      0.048
# 419            5.0              0.42         0.24             2.0      0.060
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 462                 22.0                  71.0  0.99760  2.98       0.84
# 329                  7.0                  18.0  0.99470  3.32       0.79
# 98                  27.0                  63.0  0.99160  3.68       0.79
# 898                 26.0                  60.0  0.99084  3.70       0.75
# 419                 19.0                  50.0  0.99170  3.72       0.74
#
#      alcohol  quality    Id
# 462     14.9      5.0   652
# 329     14.0      6.0   467
# 98      14.0      6.0   144
# 898     14.0      6.0  1270
# 419     14.0      8.0   588

# %% [markdown]
# ### 5. What is the data type of the density column?

# %%
df["density"].dtypes
# Out:
# dtype('float64')

# %% [markdown]
# ### 6. Check how many missing values are in the dataset?

# %%
df.isnull().sum().sum()
#df.isnull().sum() which is about how many missing values in every column.
# Out:
# 12

# %% [markdown]
# ### 7. Fill missing  parts with the appropriate technique based on each column information from the technique you learned in the class.

# %%
df.fillna(0, inplace=True)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.00             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# 0         9.4      5.0     0
# 1         9.8      5.0     1
# 2         9.8      5.0     2
# 3         9.8      6.0     3
# 4         9.4      5.0     4
# ...       ...      ...   ...
# 1138     11.0      6.0  1592
# 1139      9.5      6.0  1593
# 1140     10.5      5.0  1594
# 1141     11.2      6.0  1595
# 1142     10.2      5.0  1597
#
# [1143 rows x 13 columns]

# %% [markdown]
# ### 8. Create a simple plot of the dataframe indicating the alcohol per wine.

# %%
df.plot("Id", "alcohol")
# Out:
# <Axes: xlabel='Id'>

# %% [markdown]
# ### 9. Change the name of the column "residual sugar" to "sugar"

# %%
df.rename(columns={"residual sugar":"sugar"}, inplace=True)
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  sugar  chlorides  \
# 0            7.4              0.70         0.00    1.9      0.076
# 1            7.8              0.88         0.00    2.6      0.098
# 2            7.8              0.76         0.04    2.3      0.092
# 3           11.2              0.28         0.56    1.9      0.075
# 4            7.4              0.70         0.00    1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4      5.0   0
# 1      9.8      5.0   1
# 2      9.8      5.0   2
# 3      9.8      6.0   3
# 4      9.4      5.0   4

# %% [markdown]
# ### 10. Sort the dataset based on "quality" and "alcohol" feature.

# %%
df.sort_values(by=["quality", "alcohol"], ascending=False, inplace=True)
df
# Out:
#       fixed acidity  volatile acidity  citric acid  sugar  chlorides  \
# 419             5.0              0.42         0.24    2.0      0.060
# 321            11.3              0.62         0.67    5.2      0.086
# 793             7.9              0.54         0.34    2.5      0.076
# 271             5.6              0.85         0.05    1.4      0.045
# 190             7.9              0.35         0.46    3.6      0.078
# ...             ...               ...          ...    ...        ...
# 1046            7.3              0.98         0.05    2.1      0.061
# 324            11.6              0.58         0.66    2.2      0.074
# 368            10.4              0.61         0.49    2.1      0.200
# 1075            6.8              0.00         0.05    2.0      0.070
# 1112            7.8              0.60         0.26    2.0      0.080
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 419                  19.0                  50.0  0.99170  3.72       0.74
# 321                   6.0                  19.0  0.99880  3.22       0.69
# 793                   8.0                  17.0  0.99235  3.20       0.72
# 271                  12.0                  88.0  0.99240  3.56       0.82
# 190                  15.0                  37.0  0.99730  3.35       0.86
# ...                   ...                   ...      ...   ...        ...
# 1046                 20.0                  49.0  0.99705  3.31       0.55
# 324                  10.0                  47.0  1.00080  3.25       0.57
# 368                   5.0                  16.0  0.99940  3.16       0.63
# 1075                  6.0                  14.0  0.99562  3.51       0.66
# 1112                 31.0                 131.0  0.99622  3.21       0.52
#
#       alcohol  quality    Id
# 419      14.0      8.0   588
# 321      13.4      8.0   455
# 793      13.1      8.0  1120
# 271      12.9      8.0   390
# 190      12.8      8.0   267
# ...       ...      ...   ...
# 1046      9.7      3.0  1469
# 324       9.0      3.0   459
# 368       8.4      3.0   517
# 1075     10.8      0.0  1506
# 1112      9.9      0.0  1559
#
# [1143 rows x 13 columns]

# %% [markdown]
# ### 11. Plot the histogram of "density".

# %%
sns.histplot(data=df['alcohol'], bins=15)
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %% [markdown]
# ### 12. Plot distribution and relationship in a dataset and analyze the relationship between "fixed acidity" and "pH" columns

# %%
sns.pairplot(df[["fixed acidity", "pH"]])
# Out:
# E:\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#the relationship between "fixed acidity" and "pH" is linear, strong and negative.
